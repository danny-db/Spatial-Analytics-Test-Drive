# %%
# %pip install geopandas folium
# %restart_python

# %%
# Instantiate Python variables
CATALOG = "geo"
ELEC_SCHEMA = "electricity"
ELEC_VOLUME = "shp"
BOUND_SCHEMA = "digital_boundary"
BOUND_VOLUME = "asgs_ed_3"

# %%
# %sql
-- To ensure default catalog is not Hive Metastore
USE CATALOG geo;
