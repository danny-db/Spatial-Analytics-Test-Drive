# %% [markdown]
# # Potential use cases to explore within the Australian utility context
#
# 1. [Trace utility network](https://pro.arcgis.com/en/pro-app/latest/help/data/utility-network/about-tracing-utility-networks.htm), to understand flow direction in a utility network.
#
#   - The following datasets will be explored to enable this analysis:
#
#     - Data from the National Electricity Market (NEM). For example; [OpenNEM](https://www.aemo.com.au/energy-systems/electricity/national-electricity-market-nem/data-nem)
#
# 2. Emergency Operations and Dispatch Management
#
#   - This may require exploration of:
#
#     - Lakebase
#
# 3. Asset Inspections and Work Order Management
#
# - This may require exploration of:
#
#     - Lakebase
